# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritvik10/Question-23-MVSS-2021-Assessment/blob/main/Question_23_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import tree

# %%
df = pd.read_csv("/content/Certisured.com_MVSS_2021_Student_Feedback_Form.csv")

# %%
df
# Out:
#    Was the event well organized?  ... Would you like to become a part of our Industry Excellence Program and begin your journey towards professional mastery?
# 0                          Agree  ...                             I have different plans
# 1                 Strongly Agree  ...                                      Not right now
# 2                 Strongly Agree  ...                                      Not right now
# 3                 Strongly Agree  ...                  May be, if I get more information
# 4                 Strongly Agree  ...                  May be, if I get more information
# ..                           ...  ...                                                ...
# 57                         Agree  ...                  May be, if I get more information
# 58                         Agree  ...                   Yes, and I need more information
# 59                Strongly Agree  ...                                      Not right now
# ...

# %%
df.head()
# Out:
#   Was the event well organized?  ... Would you like to become a part of our Industry Excellence Program and begin your journey towards professional mastery?
# 0                         Agree  ...                             I have different plans
# 1                Strongly Agree  ...                                      Not right now
# 2                Strongly Agree  ...                                      Not right now
# 3                Strongly Agree  ...                  May be, if I get more information
# 4                Strongly Agree  ...                  May be, if I get more information
#
# [5 rows x 10 columns]

# %%
d= {'Y':1, 'N':0}
df['Purchase']=df['Hired'].map(d)
df['Has good ventilation']= df['Has good ventilation'].map(d)
df['Top-tier builder']= df['Top-tier builder'].map(d)
df['Interior Finished']= df['Interior Finished'].map(d)
d= {'Reasonable':0, 'High':1, 'very high':2}
df['Type']= df['Type'].map(d)
df.head(13)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Hired'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-b2b5f58321f4> in <module>()
#       1 d= {'Y':1, 'N':0}
# ...
